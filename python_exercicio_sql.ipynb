# %% [markdown]
# <a href="https://colab.research.google.com/github/cila-henriques/projeto.python.soulcode/blob/main/python_exercicio_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.3 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.46.235.151' # endereço do banco externo que eu quero acessar
user = 'root'
password = ''
database = 'locadora'

# %%
# !curl ipecho.net/plain
# Out:
# 35.186.163.154

# %%
def consulta(query, tabela):
  connection = mysql.connector.connect(
      host = host,
      user = user,
      password = password,
      database = database
  )
  cursor = connection.cursor()

  try:
    cursor.execute(query)
    result = cursor.fetchall()
    globals()[tabela] = pd.DataFrame(result, columns=cursor.column_names)
    display(globals()[tabela])
  finally:
    cursor.close()
    connection.close()

# %%
consulta(''' show tables;''','tabelas')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     334         try:
# --> 335             self._cmysql.connect(**cnx_kwargs)
#     336             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on '34.46.235.151:3306' (110)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-6-31a63edf7f52> in <cell line: 1>()
# ----> 1 consulta(''' show tables;''','tabelas')
#
# <ipython-input-5-f2f7e9bdbea3> in consulta(query, tabela)
#       1 def consulta(query, tabela):
# ----> 2   connection = mysql.connector.connect(
#       3       host = host,
#       4       user = user,
# ...

# %% [markdown]
# # SELECT

# %%
# 1. Selecione todos os dados da tabela cliente
consulta(''' select * from cliente;''', 'cliente')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %%
# 2. Liste todos os clientes que moram na cidade de "São Paulo".
consulta(''' select * from cliente where cidade = 'São Paulo';''', 'cliente')
# Out:
#    codcliente           nome     cidade sexo estado estadocivil
# 0           5  Lúcia Andrade  São Paulo    F     SP           C

# %%
# 3. Liste os estados diferentes presentes na tabela cliente.
consulta(''' select distinct estado from cliente; ''', 'cliente')
# Out:
#   estado
# 0     RJ
# 1     SP

# %%
# 4. Liste todos os clientes ordenados pelo nome em ordem alfabética
consulta(''' select * from cliente order by nome; ''', 'cliente')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           4    Fernando Souza         Campinas    M     SP           S
# 3           5     Lúcia Andrade        São Paulo    F     SP           C
# 4           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %%
# 5. Encontre todos os clientes que são do sexo feminino e solteiros
consulta(''' select * from cliente  where sexo = 'F' and estadocivil = 'S';''', 'cliente'  )
# Out:
# Empty DataFrame
# Columns: [codcliente, nome, cidade, sexo, estado, estadocivil]
# Index: []

# %%
# 6. Liste todos os clientes cujo nome começa com a letra 'A'.
consulta(''' select * from cliente where nome like 'A%'; ''', 'cliente')
# Out:
#    codcliente       nome           cidade sexo estado estadocivil
# 0           1  Ana Silva  Duque de Caxias    F     RJ           C

# %%
# 7. Selecione os 3 primeiros registros da tabela cliente.
consulta(''' select * from cliente limit 3; ''', 'cliente')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %%
# 8. Liste todos os carros que são da marca 'Ford' ou 'Fiat'.
consulta(''' select * from carro;''', 'carro')
consulta(''' select * from carro where modelo in ('Ford', 'Fiat');''', 'carro')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
# Empty DataFrame
# Columns: [codcarro, codmarca, modelo, valor]
# Index: []

# %%
# 9. Encontre todos os carros cujo valor está entre 100 e 150.
consulta(''' select * from carro where valor between 100 and 150; ''', 'carro')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         4         4   Polo  150.0
# 3         5         5   Kwid  120.0

# %%
# 10. Conte quantos aluguéis foram realizados.

consulta(''' select * from aluguel; ''', 'aluguel')
consulta (''' select count(*) from aluguel; ''', 'aluguel')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    count(*)
# 0        10

# %%
# 11. Calcule o valor total de todos os carros disponíveis para aluguel.

consulta('''SELECT SUM(valor)
FROM carro AS c
WHERE c.codcarro NOT IN (SELECT a.codcarro FROM aluguel AS a);
 ''','''NOT IN''')
# Out:
#    SUM(valor)
# 0       120.0

# %%
# 12  Calcule o valor médio dos carros.
consulta(''' select avg(valor) from carro; ''', 'carro')
# Out:
#    avg(valor)
# 0       138.0

# %%
# 13.  Encontre o menor e o maior valor de aluguel de carros.
consulta('''select min(valor), max(valor) from carro; ''', 'carro')
# Out:
#    min(valor)  max(valor)
# 0       100.0       170.0

# %%
# 14. Agrupe os clientes por estado e conte quantos clientes existem em cada estado
consulta(''' select * from cliente;''', 'cliente')

consulta(''' select estado, count(codcliente) as cliente from cliente group by estado; ''', 'cliente')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#   estado  cliente
# 0     RJ        3
# 1     SP        2

# %%
# 15. Agrupe os aluguéis por cliente e filtre apenas aqueles que fizeram mais de 2 aluguéis.
consulta(''' select * from aluguel; ''', 'aluguel')
consulta( '''select * from cliente; ''', 'cliente')
consulta(''' select codcliente, count(codaluguel) from aluguel group by codcliente having count(codaluguel) > 2; ''', 'aluguel')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# ...

# %%
# 16. Liste todos os aluguéis, mostrando o nome do cliente e o modelo do carro alugado
consulta(''' select * from marca; ''', 'marca')

consulta('''select c.nome, m.marca
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
#                nome       marca
# 0         Ana Silva  Volkswagen
# 1         Ana Silva  Volkswagen
# 2         Ana Silva        Ford
# 3     Bruna Pereira        Ford
# 4     Bruna Pereira        Ford
# 5     Bruna Pereira   Chevrolet
# 6     Lúcia Andrade        Fiat
# 7     Lúcia Andrade        Fiat
# 8  Túlio Nascimento        Fiat
# 9  Túlio Nascimento        Ford

# %%
# 17. Liste todos os carros e, se houver, as informações sobre os aluguéis realizados desses carros.
consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
consulta (''' select * from marca; ''', 'marca')
consulta(''' select c.modelo,a.data_aluguel from carro as c
join aluguel as a on c.codcarro = a.codcarro;''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
#   modelo data_aluguel
# 0     Ka   2023-04-02
# ...

# %%
# 18. Liste todos os aluguéis e as informações sobre os carros alugados, mesmo que o carro não esteja mais no banco de dados.
consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
consulta('''select c.nome,ca.modelo, a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
where ca.codcarro not in (select codcarro from aluguel)
order by c.nome; ''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
# Empty DataFrame
# Columns: [nome, modelo, data_aluguel]
# Index: []

# %%
# 19. Liste todos os clientes e os carros que alugaram, incluindo clientes que não alugaram e carros que não foram alugados.
#consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select distinct c.nome,ca.modelo, m.marca
from cliente AS c
LEFT JOIN  aluguel AS a on a.codcliente = c.codcliente
LEFT JOIN carro AS ca ON  ca.codcarro = a.codcarro
LEFT JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''left''')
# Out:
#                nome modelo       marca
# 0         Ana Silva   Polo  Volkswagen
# 1         Ana Silva     Ka        Ford
# 2     Bruna Pereira     Ka        Ford
# 3     Bruna Pereira   Onix   Chevrolet
# 4    Fernando Souza   None        None
# 5     Lúcia Andrade   Argo        Fiat
# 6  Túlio Nascimento   Argo        Fiat
# 7  Túlio Nascimento     Ka        Ford

# %%
# 20. Combine os resultados de duas consultas: uma que lista clientes solteiros e outra que lista clientes casados.
#consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select nome, estadocivil
from cliente
where estadocivil = 'C'
union select nome, estadocivil
from cliente
where estadocivil = 'S';''','casado_solteiro''' )
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#                nome estadocivil
# 0         Ana Silva           C
# 1     Bruna Pereira           C
# 2     Lúcia Andrade           C
# 3  Túlio Nascimento           S
# 4    Fernando Souza           S

# %%
# 20. Encontre os clientes que alugaram o carro com modelo 'Onix'
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,ca.modelo, a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
where ca.modelo = 'Onix'
order by c.nome; ''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
#             nome modelo data_aluguel
# 0  Bruna Pereira   Onix   2023-04-04

# %%
# 22. Liste os modelos de carros e o número de vezes que cada um foi alugado.
#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select ca.modelo, count(a.codcarro) as quantidade_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
group by ca.modelo; ''', '''inner_join''')
# Out:
#   modelo  quantidade_aluguel
# 0   Argo                   3
# 1     Ka                   4
# 2   Onix                   1
# 3   Polo                   2

# %%
# 23. Liste o nome dos clientes e o número de aluguéis que cada um fez.
#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
#consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, count(a.codcarro) as quantidade_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
group by c.nome; ''', '''inner_join''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#                nome  quantidade_aluguel
# 0  Túlio Nascimento                   2
# 1     Bruna Pereira                   3
# 2         Ana Silva                   3
# 3     Lúcia Andrade                   2

# %%
# 24 - Crie uma consulta que retorne o nome dos clientes e uma coluna adicional chamada status_civil que classifica os clientes como "Solteiro" ou "Casado".
#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''
  select nome,
  (case when estadocivil = 'C'
    then 'Casado'
    else 'Solteiro'
  end) as status_civil
from cliente; ''', '''status_civil''')
# Out:
#                nome status_civil
# 0         Ana Silva       Casado
# 1     Bruna Pereira       Casado
# 2  Túlio Nascimento     Solteiro
# 3    Fernando Souza     Solteiro
# 4     Lúcia Andrade       Casado

# %%
#25 Liste os nomes dos clientes e as datas em que alugaram carros.
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select distinct c.nome,a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#                nome data_aluguel
# 0         Ana Silva   2023-04-05
# 1         Ana Silva   2023-04-13
# 2         Ana Silva   2023-04-15
# 3     Bruna Pereira   2023-04-02
# 4     Bruna Pereira   2023-04-03
# 5     Bruna Pereira   2023-04-04
# 6     Lúcia Andrade   2023-04-19
# 7     Lúcia Andrade   2023-04-21
# 8  Túlio Nascimento   2023-04-01
# 9  Túlio Nascimento   2023-04-25

# %%
#26. Liste todos os modelos de carros e suas respectivas marcas
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select ca.modelo,m.marca
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#   modelo       marca
# 0   Polo  Volkswagen
# 1   Polo  Volkswagen
# 2     Ka        Ford
# 3     Ka        Ford
# 4     Ka        Ford
# 5   Onix   Chevrolet
# 6   Argo        Fiat
# 7   Argo        Fiat
# 8   Argo        Fiat
# 9     Ka        Ford

# %%
# 27. Liste todos os aluguéis e os nomes dos clientes que os realizaram.
# consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# ...

# %%
# 28. Encontre o nome dos clientes e os modelos de carros que alugaram..
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#                nome modelo
# 0         Ana Silva   Polo
# 1         Ana Silva   Polo
# 2         Ana Silva     Ka
# 3     Bruna Pereira     Ka
# 4     Bruna Pereira     Ka
# 5     Bruna Pereira   Onix
# 6     Lúcia Andrade   Argo
# 7     Lúcia Andrade   Argo
# 8  Túlio Nascimento   Argo
# 9  Túlio Nascimento     Ka

# %%
# 29. Liste todos os carros e, se houver, mostre as datas em que foram alugados.
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select ca.modelo, a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#   modelo data_aluguel
# 0   Polo   2023-04-05
# 1   Polo   2023-04-13
# 2     Ka   2023-04-15
# 3     Ka   2023-04-02
# 4     Ka   2023-04-03
# 5   Onix   2023-04-04
# 6   Argo   2023-04-19
# 7   Argo   2023-04-21
# 8   Argo   2023-04-01
# 9     Ka   2023-04-25

# %%
# 30. Encontre os clientes que moram na mesma cidade e estado e que alugaram carros

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''SELECT DISTINCT c1.nome AS cliente1, c2.nome AS cliente2, c1.cidade, c1.estado
FROM cliente AS c1
JOIN cliente AS c2 ON c1.cidade = c2.cidade
                   AND c1.estado = c2.estado
                   AND c1.codcliente <> c2.codcliente
JOIN aluguel AS a1 ON c1.codcliente = a1.codcliente
JOIN aluguel AS a2 ON c2.codcliente = a2.codcliente
ORDER BY c1.cidade, c1.estado, cliente1, cliente2;
''', '''inner_join''')
# Out:
#            cliente1          cliente2           cidade estado
# 0         Ana Silva  Túlio Nascimento  Duque de Caxias     RJ
# 1  Túlio Nascimento         Ana Silva  Duque de Caxias     RJ

# %%
# 31. Liste os nomes dos clientes e os carros que eles alugaram, incluindo os clientes que não alugaram nenhum carro

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo
from cliente AS c
LEFT JOIN aluguel AS a on c.codcliente = a.codcliente
LEFT JOIN carro AS ca ON a.codcarro = ca.codcarro
LEFT JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#                 nome modelo
# 0          Ana Silva   Polo
# 1          Ana Silva   Polo
# 2          Ana Silva     Ka
# 3      Bruna Pereira     Ka
# 4      Bruna Pereira     Ka
# 5      Bruna Pereira   Onix
# 6     Fernando Souza   None
# 7      Lúcia Andrade   Argo
# 8      Lúcia Andrade   Argo
# 9   Túlio Nascimento   Argo
# 10  Túlio Nascimento     Ka

# %%
# 32. Liste todas as marcas e, se houver, os modelos de carros associados.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select m.marca, ca.modelo
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#         marca modelo
# 0  Volkswagen   Polo
# 1  Volkswagen   Polo
# 2        Ford     Ka
# 3        Ford     Ka
# 4        Ford     Ka
# 5   Chevrolet   Onix
# 6        Fiat   Argo
# 7        Fiat   Argo
# 8        Fiat   Argo
# 9        Ford     Ka

# %%
# 33. Encontre todos os aluguéis e o estado civil dos clientes que alugaram os carros.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select a.codaluguel,c.nome,c.estadocivil
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#    codaluguel              nome estadocivil
# 0           5         Ana Silva           C
# 1           6         Ana Silva           C
# 2           7         Ana Silva           C
# 3           2     Bruna Pereira           C
# 4           3     Bruna Pereira           C
# 5           4     Bruna Pereira           C
# 6           8     Lúcia Andrade           C
# 7           9     Lúcia Andrade           C
# 8           1  Túlio Nascimento           S
# 9          10  Túlio Nascimento           S

# %%
# 34. Liste os clientes e as cidades em que moram para aqueles que alugaram carros.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,c.cidade
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#                nome           cidade
# 0         Ana Silva  Duque de Caxias
# 1         Ana Silva  Duque de Caxias
# 2         Ana Silva  Duque de Caxias
# 3     Bruna Pereira          Niterói
# 4     Bruna Pereira          Niterói
# 5     Bruna Pereira          Niterói
# 6     Lúcia Andrade        São Paulo
# 7     Lúcia Andrade        São Paulo
# 8  Túlio Nascimento  Duque de Caxias
# 9  Túlio Nascimento  Duque de Caxias

# %%
# 35. Liste os clientes que alugaram carros e os modelos de carros que eles alugaram, incluindo a marca do carro.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,ca.modelo,m.marca
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
order by c.nome; ''', '''inner_join''')
# Out:
#                nome modelo       marca
# 0         Ana Silva   Polo  Volkswagen
# 1         Ana Silva   Polo  Volkswagen
# 2         Ana Silva     Ka        Ford
# 3     Bruna Pereira     Ka        Ford
# 4     Bruna Pereira     Ka        Ford
# 5     Bruna Pereira   Onix   Chevrolet
# 6     Lúcia Andrade   Argo        Fiat
# 7     Lúcia Andrade   Argo        Fiat
# 8  Túlio Nascimento   Argo        Fiat
# 9  Túlio Nascimento     Ka        Ford

# %%
# 36. Encontre todos os aluguéis realizados em uma cidade específica e liste os nomes dos clientes e os modelos de carros alugados.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,ca.modelo,m.marca,a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
where c.cidade = 'Duque de Caxias'
order by c.nome; ''', '''inner_join''')
# Out:
#                nome modelo       marca data_aluguel
# 0         Ana Silva   Polo  Volkswagen   2023-04-05
# 1         Ana Silva   Polo  Volkswagen   2023-04-13
# 2         Ana Silva     Ka        Ford   2023-04-15
# 3  Túlio Nascimento   Argo        Fiat   2023-04-01
# 4  Túlio Nascimento     Ka        Ford   2023-04-25

# %%
# 37. Liste os modelos de carros e a quantidade de vezes que foram alugados.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select ca.modelo, count(ca.modelo) as qunatidade_modelo
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by ca.modelo;
''', '''inner_join''')
# Out:
#   modelo  qunatidade_modelo
# 0   Argo                  3
# 1     Ka                  4
# 2   Onix                  1
# 3   Polo                  2

# %%
# 38. Encontre os clientes que alugaram mais de um carro.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,ca.modelo, count(ca.modelo) as quatidade_modelo
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by c.nome,ca.modelo
having quatidade_modelo > 1 ;
''', '''inner_join''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#             nome modelo  quatidade_modelo
# 0  Bruna Pereira     Ka                 2
# 1  Lúcia Andrade   Argo                 2
# 2      Ana Silva   Polo                 2

# %%
# 39. Liste os clientes, as datas de aluguel e o valor do carro alugado..

#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,a.data_aluguel, ca.valor
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
;
''', '''inner_join''')
# Out:
#                nome data_aluguel  valor
# 0     Bruna Pereira   2023-04-02  100.0
# 1     Bruna Pereira   2023-04-03  100.0
# 2         Ana Silva   2023-04-15  100.0
# 3  Túlio Nascimento   2023-04-25  100.0
# 4  Túlio Nascimento   2023-04-01  150.0
# 5     Lúcia Andrade   2023-04-19  150.0
# 6     Lúcia Andrade   2023-04-21  150.0
# 7     Bruna Pereira   2023-04-04  170.0
# 8         Ana Silva   2023-04-05  150.0
# 9         Ana Silva   2023-04-13  150.0

# %%
# 40. Liste os modelos de carros que nunca foram alugados.

# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select modelo
from carro where codcarro not in( select codcarro from aluguel);
''', '''carro''')
# Out:
#   modelo
# 0   Kwid

# %%
# 41. Encontre os clientes que alugaram carros e o total gasto em aluguéis

#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome,sum(ca.valor)
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by c.nome;
''', '''inner_join''')
# Out:
#                nome  sum(ca.valor)
# 0  Túlio Nascimento          250.0
# 1     Bruna Pereira          370.0
# 2         Ana Silva          400.0
# 3     Lúcia Andrade          300.0

# %%
# 42. Liste as marcas de carros e o número total de aluguéis por marca.

#consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select m.marca,count( m.marca)
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by  m.marca;
''', '''inner_join''')
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
#         marca  count( m.marca)
# 0        Fiat                3
# 1        Ford                4
# 2   Chevrolet                1
# 3  Volkswagen                2

# %%
# 43. Encontre os clientes que alugaram carros em um determinado mês e ano, listando os modelos de carros e as datas de aluguel..

# consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo , a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
WHERE EXTRACT(MONTH FROM a.data_aluguel) = 04
  AND EXTRACT(YEAR FROM a.data_aluguel) = 2023;
''', '''inner_join''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3202b55ec045> in <cell line: 8>()
#       6 # consulta (''' select * from cliente; ''', 'cliente')
#       7
# ----> 8 consulta('''select c.nome, ca.modelo , a.data_aluguel
#       9 from aluguel AS a
#      10 join cliente AS c on a.codcliente = c.codcliente
#
# NameError: name 'consulta' is not defined

# %%
# 44. Liste os clientes que moram em estados diferentes e que alugaram carros, junto com os modelos alugados.

# consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select distinct c.nome, c.estado
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
WHERE EXTRACT(MONTH FROM a.data_aluguel) = 04
  AND EXTRACT(YEAR FROM a.data_aluguel) = 2023;
''', '''inner_join''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#                nome estado
# 0     Bruna Pereira     RJ
# 1         Ana Silva     RJ
# 2  Túlio Nascimento     RJ
# 3     Lúcia Andrade     SP

# %%
# 45. Encontre os clientes que alugaram carros, os modelos de carros alugados, as marcas desses carros e as datas de aluguel, ordenando pelos nomes dos clientes.

consulta('''select * from carro; ''', 'carro')
#consulta ('''select * from aluguel; ''', 'aluguel')
consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select distinct c.nome,ca.modelo,m.marca, a.data_aluguel
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
WHERE EXTRACT(MONTH FROM a.data_aluguel) = 04
  AND EXTRACT(YEAR FROM a.data_aluguel) = 2023
order by c.nome asc;
''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C
#                nome modelo       marca data_aluguel
# 0         Ana Silva   Polo  Volkswagen   2023-04-05
# 1         Ana Silva   Polo  Volkswagen   2023-04-13
# ...

# %%
# 46. Liste os clientes que alugaram carros mais de uma vez e os detalhes dos carros que alugaram.
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, count(a.codcliente) as quantidade
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by c.nome
having count(a.codcliente) > 1;
''', '''inner_join''')
# Out:
#                nome  quantidade
# 0  Túlio Nascimento           2
# 1     Bruna Pereira           3
# 2         Ana Silva           3
# 3     Lúcia Andrade           2

# %%
# 47. Encontre os modelos de carros que foram alugados por clientes de cidades específicas e liste as marcas desses carros.
consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select ca.modelo, m.marca
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
where c.cidade = 'Duque de Caxias';
''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
# ...

# %%
# 48. Liste os clientes que alugaram carros, os modelos e as marcas dos carros, e o total gasto em aluguéis, agrupado por cliente.
consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo, m.marca, sum(ca.valor) as total
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
group by c.nome, ca.modelo, m.marca;
''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
# ...

# %%
# 49. Encontre os carros que foram alugados nos últimos 30 dias e os clientes que os alugaram.
# consulta('''select * from carro; ''', 'carro')
# consulta ('''select * from aluguel; ''', 'aluguel')
# consulta (''' select * from marca; ''', 'marca')
# consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo, m.marca
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
WHERE a.data_aluguel >= CURDATE() - INTERVAL 30 DAY;
''', '''inner_join''')
# Out:
# Empty DataFrame
# Columns: [nome, modelo, marca]
# Index: []

# %%
#50. Liste os clientes, os carros que alugaram, as marcas desses carros, e o valor total gasto em aluguéis, filtrando por um intervalo de datas específico.
consulta('''select * from carro; ''', 'carro')
consulta ('''select * from aluguel; ''', 'aluguel')
consulta (''' select * from marca; ''', 'marca')
consulta (''' select * from cliente; ''', 'cliente')

consulta('''select c.nome, ca.modelo, m.marca, sum(ca.valor) as total
from aluguel AS a
join cliente AS c on a.codcliente = c.codcliente
JOIN carro AS ca ON a.codcarro = ca.codcarro
JOIN marca AS m ON m.codmarca = ca.codmarca
where a.data_aluguel >= '2023-04-01' and a.data_aluguel <='2023-04-30'
group by c.nome, ca.modelo, m.marca;
''', '''inner_join''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault
# ...
